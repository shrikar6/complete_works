# %%
# This script builds an extensive network graph using NetworkX, where each node represents a company and each edge
# represents that the two companies are widely considered to be direct competitors. It then creates an interactive
# visualization of the graph and saves it as an HTML file ('graph.html').

# %%
from pyvis.network import Network
import networkx as nx

# %%
G = nx.Graph()

G.add_nodes_from(["msft", "orcl", "crm", "googl"])
G.add_edges_from([("msft", "orcl"), ("msft", "crm"), ("msft", "googl")])

G.add_nodes_from(["orcl", "crm", "wday", "msft", "sap"])
G.add_edges_from([("orcl", "crm"), ("orcl", "wday"), ("orcl", "msft"), ("orcl", "sap")])

G.add_nodes_from(["crm", "adbe", "orcl", "msft", "pega"])
G.add_edges_from([("crm", "adbe"), ("crm", "orcl"), ("crm", "msft"), ("crm", "pega")])

G.add_nodes_from(["googl", "aapl", "amzn", "msft", "meta", "vz", "snap"])
G.add_edges_from([("googl", "aapl"), ("googl", "amzn"), ("googl", "msft"), ("googl", "meta"), ("googl", "vz"), ("googl", "snap")])

G.add_nodes_from(["wday", "orcl", "crm", "sap"])
G.add_edges_from([("wday", "orcl"), ("wday", "crm"), ("wday", "sap")])

G.add_nodes_from(["sap", "orcl", "wday", "ibm"])
G.add_edges_from([("sap", "orcl"), ("sap", "wday"), ("sap", "ibm")])

G.add_nodes_from(["adbe", "orcl", "crm", "msft"])
G.add_edges_from([("adbe", "orcl"), ("adbe", "crm"), ("adbe", "msft")])

G.add_nodes_from(["pega", "crm", "msft", "now", "team"])
G.add_edges_from([("pega", "crm"), ("pega", "msft"), ("pega", "now"), ("pega", "team")])

G.add_nodes_from(["aapl", "samsung (005930)", "googl", "msft"])
G.add_edges_from([("aapl", "samsung (005930)"), ("aapl", "googl"), ("aapl", "msft")])

G.add_nodes_from(["amzn", "wmt", "ebay", "msft"])
G.add_edges_from([("amzn", "wmt"), ("amzn", "ebay"), ("amzn", "msft")])

G.add_nodes_from(["meta", "googl", "vz", "snap"])
G.add_edges_from([("meta", "googl"), ("meta", "vz"), ("meta", "snap")])

G.add_nodes_from(["vz", "tmus", "cmcsa", "t"])
G.add_edges_from([("vz", "tmus"), ("vz", "cmcsa"), ("vz", "t")])

G.add_nodes_from(["snap", "pins", "googl", "meta"])
G.add_edges_from([("snap", "pins"), ("snap", "googl"), ("snap", "meta")])

G.add_nodes_from(["ibm", "orcl", "hpq", "msft", "acn"])
G.add_edges_from([("ibm", "orcl"), ("ibm", "hpq"), ("ibm", "msft"), ("ibm", "acn")])

G.add_nodes_from(["now", "crm", "msft", "team"])
G.add_edges_from([("now", "crm"), ("now", "msft"), ("now", "team")])

G.add_nodes_from(["team", "msft", "now"])
G.add_edges_from([("team", "msft"), ("team", "now")])

G.add_nodes_from(["samsung (005930)", "sk hynix (000660)", "aapl", "mu", "tsm"])
G.add_edges_from([("samsung (005930)", "sk hynix (000660)"), ("samsung (005930)", "aapl"), ("samsung (005930)", "mu"), ("samsung (005930)", "tsm")])

G.add_nodes_from(["wmt", "cost", "tgt", "amzn", "kr"])
G.add_edges_from([("wmt", "cost"), ("wmt", "tgt"), ("wmt", "amzn"), ("wmt", "kr")])

G.add_nodes_from(["ebay", "baba", "meli", "amzn"])
G.add_edges_from([("ebay", "baba"), ("ebay", "meli"), ("ebay", "amzn")])

G.add_nodes_from(["tmus", "cmcsa", "t", "vz"])
G.add_edges_from([("tmus", "cmcsa"), ("tmus", "t"), ("tmus", "vz")])

G.add_nodes_from(["cmcsa", "vz", "dis"])
G.add_edges_from([("cmcsa", "vz"), ("cmcsa", "dis")])

G.add_nodes_from(["t", "tmus", "chtr", "cmcsa", "vz"])
G.add_edges_from([("t", "tmus"), ("t", "chtr"), ("t", "cmcsa"), ("t", "vz")])

G.add_nodes_from(["pins", "googl", "meta", "snap"])
G.add_edges_from([("pins", "googl"), ("pins", "meta"), ("pins", "snap")])

G.add_nodes_from(["hpq", "dell", "lenovo (00992)", "xrx"])
G.add_edges_from([("hpq", "dell"), ("hpq", "lenovo (00992)"), ("hpq", "xrx")])

G.add_nodes_from(["acn", "cap", "ctsh", "ibm"])
G.add_edges_from([("acn", "cap"), ("acn", "ctsh"), ("acn", "ibm")])

G.add_nodes_from(["sk hynix (000660)", "samsung (005930)", "mu"])
G.add_edges_from([("sk hynix (000660)", "samsung (005930)"), ("sk hynix (000660)", "mu")])

G.add_nodes_from(["mu", "samsung (005930)", "sk hynix (000660)", "wdc"])
G.add_edges_from([("mu", "samsung (005930)"), ("mu", "sk hynix (000660)"), ("mu", "wdc")])

G.add_nodes_from(["tsm", "intc", "gfs", "samsung (005930)", "umc (2303)"])
G.add_edges_from([("tsm", "intc"), ("tsm", "gfs"), ("tsm", "samsung (005930)"), ("tsm", "umc (2303)")])

G.add_nodes_from(["cost", "tgt", "wmt", "kr"])
G.add_edges_from([("cost", "tgt"), ("cost", "wmt"), ("cost", "kr")])

G.add_nodes_from(["tgt", "dg", "wmt", "dltr"])
G.add_edges_from([("tgt", "dg"), ("tgt", "wmt"), ("tgt", "dltr")])

G.add_nodes_from(["kr", "cost", "tgt", "wmt", "aci"])
G.add_edges_from([("kr", "cost"), ("kr", "tgt"), ("kr", "wmt"), ("kr", "aci")])

G.add_nodes_from(["baba", "meituan (03690)", "tencent (00700)", "bidu", "jd"])
G.add_edges_from([("baba", "meituan (03690)"), ("baba", "tencent (00700)"), ("baba", "bidu"), ("baba", "jd")])

G.add_nodes_from(["meli", "pypl", "baba", "amzn"])
G.add_edges_from([("meli", "pypl"), ("meli", "baba"), ("meli", "amzn")])

G.add_nodes_from(["dis", "wbd", "cmcsa", "nflx"])
G.add_edges_from([("dis", "wbd"), ("dis", "cmcsa"), ("dis", "nflx")])

G.add_nodes_from(["chtr", "lumn", "vz"])
G.add_edges_from([("chtr", "lumn"), ("chtr", "vz")])

G.add_nodes_from(["dell", "hpe", "hpq", "lenovo (00992)"])
G.add_edges_from([("dell", "hpe"), ("dell", "hpq"), ("dell", "lenovo (00992)")])

G.add_nodes_from(["lenovo (00992)", "hpq", "dell", "xiaomi (01810)"])
G.add_edges_from([("lenovo (00992)", "hpq"), ("lenovo (00992)", "dell"), ("lenovo (00992)", "xiaomi (01810)")])

G.add_nodes_from(["xrx", "hpq", "kyocy", "ibm"])
G.add_edges_from([("xrx", "hpq"), ("xrx", "kyocy"), ("xrx", "ibm")])

G.add_nodes_from(["cap", "infy", "acn", "ctsh"])
G.add_edges_from([("cap", "infy"), ("cap", "acn"), ("cap", "ctsh")])

G.add_nodes_from(["ctsh", "wit", "infy", "acn"])
G.add_edges_from([("ctsh", "wit"), ("ctsh", "infy"), ("ctsh", "acn")])

G.add_nodes_from(["wdc", "samsung (005930)", "stx", "mu"])
G.add_edges_from([("wdc", "samsung (005930)"), ("wdc", "stx"), ("wdc", "mu")])

G.add_nodes_from(["intc", "nvda", "amd"])
G.add_edges_from([("intc", "nvda"), ("intc", "amd")])

G.add_nodes_from(["gfs", "tsm", "smic (00981)", "hua hong (01347)", "umc (2303)"])
G.add_edges_from([("gfs", "tsm"), ("gfs", "smic (00981)"), ("gfs", "hua hong (01347)"), ("gfs", "umc (2303)")])

G.add_nodes_from(["umc (2303)", "tsm", "intc", "gfs", "smic (00981)"])
G.add_edges_from([("umc (2303)", "tsm"), ("umc (2303)", "intc"), ("umc (2303)", "gfs"), ("umc (2303)", "smic (00981)")])

G.add_nodes_from(["dg", "tgt", "wmt", "dltr"])
G.add_edges_from([("dg", "tgt"), ("dg", "wmt"), ("dg", "dltr")])

G.add_nodes_from(["dltr", "dg", "tgt", "wmt"])
G.add_edges_from([("dltr", "dg"), ("dltr", "tgt"), ("dltr", "wmt")])

G.add_nodes_from(["aci", "kr", "ad"])
G.add_edges_from([("aci", "kr"), ("aci", "ad")])

G.add_nodes_from(["meituan (03690)", "pdd", "tcom", "baba"])
G.add_edges_from([("meituan (03690)", "pdd"), ("meituan (03690)", "tcom"), ("meituan (03690)", "baba")])

G.add_nodes_from(["tencent (00700)", "ntes", "baba", "bidu", "cmge (00302)"])
G.add_edges_from([("tencent (00700)", "ntes"), ("tencent (00700)", "baba"), ("tencent (00700)", "bidu"), ("tencent (00700)", "cmge (00302)")])

G.add_nodes_from(["bidu", "meituan (03690)", "tencent (00700)", "baba", "jd"])
G.add_edges_from([("bidu", "meituan (03690)"), ("bidu", "tencent (00700)"), ("bidu", "baba"), ("bidu", "jd")])

G.add_nodes_from(["jd", "meituan (03690)", "pdd", "baba"])
G.add_edges_from([("jd", "meituan (03690)"), ("jd", "pdd"), ("jd", "baba")])

G.add_nodes_from(["pypl", "v", "sq", "ma"])
G.add_edges_from([("pypl", "v"), ("pypl", "sq"), ("pypl", "ma")])

G.add_nodes_from(["wbd", "para", "nflx", "dis"])
G.add_edges_from([("wbd", "para"), ("wbd", "nflx"), ("wbd", "dis")])

G.add_nodes_from(["nflx", "wbd", "cmcsa", "dis"])
G.add_edges_from([("nflx", "wbd"), ("nflx", "cmcsa"), ("nflx", "dis")])

G.add_nodes_from(["lumn", "chtr", "cmcsa", "t"])
G.add_edges_from([("lumn", "chtr"), ("lumn", "cmcsa"), ("lumn", "t")])

G.add_nodes_from(["hpe", "dell", "csco", "anet"])
G.add_edges_from([("hpe", "dell"), ("hpe", "csco"), ("hpe", "anet")])

G.add_nodes_from(["xiaomi (01810)", "lenovo (00992)", "samsung (005930)", "aapl"])
G.add_edges_from([("xiaomi (01810)", "lenovo (00992)"), ("xiaomi (01810)", "samsung (005930)"), ("xiaomi (01810)", "aapl")])

G.add_nodes_from(["kyocy", "taiyo yuden (6976)", "murata (6981)", "tdk (6762)"])
G.add_edges_from([("kyocy", "taiyo yuden (6976)"), ("kyocy", "murata (6981)"), ("kyocy", "tdk (6762)")])

G.add_nodes_from(["infy", "wit", "tcs", "acn", "ctsh"])
G.add_edges_from([("infy", "wit"), ("infy", "tcs"), ("infy", "acn"), ("infy", "ctsh")])

G.add_nodes_from(["wit", "infy", "acn", "ctsh"])
G.add_edges_from([("wit", "infy"), ("wit", "acn"), ("wit", "ctsh")])

G.add_nodes_from(["stx", "sk hynix (000660)", "wdc", "mu"])
G.add_edges_from([("stx", "sk hynix (000660)"), ("stx", "wdc"), ("stx", "mu")])

G.add_nodes_from(["nvda", "intc", "qcom", "amd"])
G.add_edges_from([("nvda", "intc"), ("nvda", "qcom"), ("nvda", "amd")])

G.add_nodes_from(["amd", "nvda", "intc"])
G.add_edges_from([("amd", "nvda"), ("amd", "intc")])

G.add_nodes_from(["smic (00981)", "tsm", "intc", "samsung (005930)", "umc (2303)"])
G.add_edges_from([("smic (00981)", "tsm"), ("smic (00981)", "intc"), ("smic (00981)", "samsung (005930)"), ("smic (00981)", "umc (2303)")])

G.add_nodes_from(["hua hong (01347)", "tsm", "samsung (005930)", "smic (00981)", "umc (2303)"])
G.add_edges_from([("hua hong (01347)", "tsm"), ("hua hong (01347)", "samsung (005930)"), ("hua hong (01347)", "smic (00981)"), ("hua hong (01347)", "umc (2303)")])

G.add_nodes_from(["qcom", "intc", "avgo", "mediatek (2454)"])
G.add_edges_from([("qcom", "intc"), ("qcom", "avgo"), ("qcom", "mediatek (2454)")])

G.add_nodes_from(["tcs", "wit", "infy", "acn", "ctsh"])
G.add_edges_from([("tcs", "wit"), ("tcs", "infy"), ("tcs", "acn"), ("tcs", "ctsh")])

G.add_nodes_from(["para", "wbd", "foxa", "dis"])
G.add_edges_from([("para", "wbd"), ("para", "foxa"), ("para", "dis")])

G.add_nodes_from(["foxa", "wbd", "para", "dis"])
G.add_edges_from([("foxa", "wbd"), ("foxa", "para"), ("foxa", "dis")])

G.add_nodes_from(["ad", "ca", "kr", "tesco"])
G.add_edges_from([("ad", "ca"), ("ad", "kr"), ("ad", "tesco")])

G.add_nodes_from(["pdd", "meituan (03690)", "jd", "baba"])
G.add_edges_from([("pdd", "meituan (03690)"), ("pdd", "jd"), ("pdd", "baba")])

G.add_nodes_from(["tcom", "meituan (03690)", "bkng", "trip", "tongcheng (00780)"])
G.add_edges_from([("tcom", "meituan (03690)"), ("tcom", "bkng"), ("tcom", "trip"), ("tcom", "tongcheng (00780)")])

G.add_nodes_from(["anet", "hpe", "dell", "csco"])
G.add_edges_from([("anet", "hpe"), ("anet", "dell"), ("anet", "csco")])

G.add_nodes_from(["csco", "hpe", "anet", "panw", "ftnt"])
G.add_edges_from([("csco", "hpe"), ("csco", "anet"), ("csco", "panw"), ("csco", "ftnt")])

G.add_nodes_from(["ca", "wmt", "ad", "tesco"])
G.add_edges_from([("ca", "wmt"), ("ca", "ad"), ("ca", "tesco")])

G.add_nodes_from(["tesco", "ca", "wmt", "sbry"])
G.add_edges_from([("tesco", "wmt"), ("tesco", "ca"), ("tesco", "sbry")])

G.add_nodes_from(["sbry", "ca", "wmt", "tesco"])
G.add_edges_from([("sbry", "wmt"), ("sbry", "ca"), ("sbry", "tesco")])

G.add_nodes_from(["ntes", "tencent (00700)", "ttwo", "cmge (00302)"])
G.add_edges_from([("ntes", "tencent (00700)"), ("ntes", "ttwo"), ("ntes", "cmge (00302)")])

G.add_nodes_from(["cmge (00302)", "tencent (00700)", "ttwo", "ntes"])
G.add_edges_from([("cmge (00302)", "tencent (00700)"), ("cmge (00302)", "ttwo"), ("cmge (00302)", "ntes")])

G.add_nodes_from(["ttwo", "rblx", "ea", "ubi"])
G.add_edges_from([("ttwo", "rblx"), ("ttwo", "ea"), ("ttwo", "ubi")])

G.add_nodes_from(["panw", "crwd", "ftnt", "csco"])
G.add_edges_from([("panw", "crwd"), ("panw", "ftnt"), ("panw", "csco")])

G.add_nodes_from(["ftnt", "crwd", "panw", "csco"])
G.add_edges_from([("ftnt", "crwd"), ("ftnt", "panw"), ("ftnt", "csco")])

G.add_nodes_from(["crwd", "ftnt", "panw", "msft"])
G.add_edges_from([("crwd", "ftnt"), ("crwd", "panw"), ("crwd", "msft")])

G.add_nodes_from(["avgo", "mrvl", "qcom", "swks"])
G.add_edges_from([("avgo", "mrvl"), ("avgo", "qcom"), ("avgo", "swks")])

G.add_nodes_from(["mediatek (2454)", "qcom", "swks", "qrvo"])
G.add_edges_from([("mediatek (2454)", "qcom"), ("mediatek (2454)", "swks"), ("mediatek (2454)", "qrvo")])

G.add_nodes_from(["swks", "avgo", "qrvo", "qcom"])
G.add_edges_from([("swks", "qrvo"), ("swks", "qcom"), ("swks", "avgo")])

G.add_nodes_from(["qrvo", "avgo", "swks", "qcom"])
G.add_edges_from([("qrvo", "swks"), ("qrvo", "qcom"), ("qrvo", "avgo")])

G.add_nodes_from(["mrvl", "avgo", "nvda", "intc"])
G.add_edges_from([("mrvl", "avgo"), ("mrvl", "nvda"), ("mrvl", "intc")])

G.add_nodes_from(["v", "axp", "ma", "dfs"])
G.add_edges_from([("v", "axp"), ("v", "ma"), ("v", "dfs")])

G.add_nodes_from(["ma", "axp", "v", "dfs"])
G.add_edges_from([("ma", "axp"), ("ma", "v"), ("ma", "dfs")])

G.add_nodes_from(["axp", "cof", "v", "dfs"])
G.add_edges_from([("axp", "cof"), ("axp", "v"), ("axp", "dfs")])

G.add_nodes_from(["dfs", "cof", "ma", "axp"])
G.add_edges_from([("dfs", "cof"), ("dfs", "ma"), ("dfs", "axp")])

G.add_nodes_from(["cof", "dfs", "syf", "axp"])
G.add_edges_from([("cof", "dfs"), ("cof", "syf"), ("cof", "axp")])

G.add_nodes_from(["sq", "pypl", "gpn", "fi"])
G.add_edges_from([("sq", "pypl"), ("sq", "gpn"), ("sq", "fi")])

G.add_nodes_from(["syf", "dfs", "cof", "bfh"])
G.add_edges_from([("syf", "dfs"), ("syf", "cof"), ("syf", "bfh")])

G.add_nodes_from(["bfh", "syf", "dfs"])
G.add_edges_from([("bfh", "dfs"), ("bfh", "syf")])

G.add_nodes_from(["gpn", "jkhy", "fis", "fi"])
G.add_edges_from([("gpn", "jkhy"), ("gpn", "fis"), ("gpn", "fi")])

G.add_nodes_from(["fi", "jkhy", "fis", "gpn"])
G.add_edges_from([("fi", "jkhy"), ("fi", "fis"), ("fi", "gpn")])

G.add_nodes_from(["jkhy", "fi", "fis", "v"])
G.add_edges_from([("fi", "jkhy"), ("jkhy", "fis"), ("jkhy", "v")])

G.add_nodes_from(["fis", "jkhy", "fi", "gpn"])
G.add_edges_from([("fis", "jkhy"), ("fis", "fi"), ("fis", "gpn")])

G.add_nodes_from(["taiyo yuden (6976)", "yageo (2327)", "semco (009150)", "tdk (6762)"])
G.add_edges_from([("taiyo yuden (6976)", "yageo (2327)"), ("taiyo yuden (6976)", "semco (009150)"), ("taiyo yuden (6976)", "tdk (6762)")])

G.add_nodes_from(["tdk (6762)", "taiyo yuden (6976)", "murata (6981)", "kyocy"])
G.add_edges_from([("tdk (6762)", "taiyo yuden (6976)"), ("tdk (6762)", "murata (6981)"), ("kyocy", "tdk (6762)")])

G.add_nodes_from(["murata (6981)", "tdk (6762)", "taiyo yuden (6976)", "kyocy", "yageo (2327)", "semco (009150)"])
G.add_edges_from([("murata (6981)", "taiyo yuden (6976)"), ("tdk (6762)", "murata (6981)"), ("kyocy", "murata (6981)"), ("murata (6981)", "yageo (2327)"), ("murata (6981)", "semco (009150)")])

G.add_nodes_from(["yageo (2327)", "taiyo yuden (6976)", "murata (6981)", "tdk (6762)"])
G.add_edges_from([("yageo (2327)", "taiyo yuden (6976)"), ("yageo (2327)", "murata (6981)"), ("yageo (2327)", "tdk (6762)")])

G.add_nodes_from(["semco (009150)", "murata (6981)", "tdk (6762)", "taiyo yuden (6976)", "yageo (2327)"])
G.add_edges_from([("semco (009150)", "taiyo yuden (6976)"), ("tdk (6762)", "semco (009150)"), ("semco (009150)", "murata (6981)"), ("semco (009150)", "yageo (2327)")])

G.add_nodes_from(["bkng", "expe", "abnb", "trip"])
G.add_edges_from([("bkng", "expe"), ("bkng", "abnb"), ("bkng", "trip")])

G.add_nodes_from(["trip", "bkng", "expe", "abnb"])
G.add_edges_from([("trip", "expe"), ("trip", "abnb"), ("bkng", "trip")])

G.add_nodes_from(["expe", "trip", "bkng", "abnb"])
G.add_edges_from([("trip", "expe"), ("expe", "abnb"), ("bkng", "expe")])

G.add_nodes_from(["abnb", "expe", "trip", "bkng"])
G.add_edges_from([("trip", "abnb"), ("expe", "abnb"), ("bkng", "abnb")])

G.add_nodes_from(["tongcheng (00780)", "meituan (03690)", "tcom"])
G.add_edges_from([("tongcheng (00780)", "meituan (03690)"), ("tcom", "tongcheng (00780)")])

G.add_nodes_from(["rblx"])

G.add_nodes_from(["ea", "ttwo"])
G.add_edges_from([("ea", "ttwo")])

G.add_nodes_from(["ubi", "ea", "ttwo"])
G.add_edges_from([("ubi", "ttwo"), ("ubi", "ea")])

G.add_edges_from([("unh", "cvs"), ("unh", "hum"), ("unh", "elv"), ("unh", "ci"), ("unh", "cnc")])

G.add_edges_from([("cvs", "unh"), ("cvs", "hum"), ("cvs", "elv"), ("cvs", "ci"), ("cvs", "wba")])

G.add_edges_from([("hum", "unh"), ("cvs", "hum"), ("hum", "elv"), ("hum", "ci"), ("hum", "cnc")])

G.add_edges_from([("elv", "unh"), ("cvs", "elv"), ("hum", "elv"), ("elv", "ci"), ("elv", "cnc")])

G.add_edges_from([("ci", "unh"), ("cvs", "ci"), ("hum", "ci"), ("elv", "ci"), ("ci", "cnc")])

G.add_edges_from([("cnc", "unh"), ("cvs", "cnc"), ("hum", "cnc"), ("elv", "cnc"), ("ci", "cnc")])

G.add_edges_from([("wba", "dg"), ("wba", "wmt"), ("wba", "cvs")])

G.add_edges_from([("hd", "tgt"), ("hd", "low"), ("hd", "tsco")])

G.add_edges_from([("low", "wmt"), ("hd", "low"), ("low", "tsco")])

G.add_edges_from([("tsco", "tgt"), ("hd", "tsco"), ("low", "tsco")])

G.add_edges_from([("lin", "apd"), ("lin", "ai"), ("lin", "ppg")])

G.add_edges_from([("apd", "lin"), ("apd", "ai"), ("apd", "ppg")])

G.add_edges_from([("ai", "lin"), ("apd", "ai"), ("ai", "ppg")])

G.add_edges_from([("ppg", "mas"), ("ppg", "shw"), ("ppg", "akza")])

G.add_edges_from([("mas", "fbin"), ("mas", "shw"), ("ppg", "mas")])

G.add_edges_from([("shw", "mas"), ("ppg", "shw"), ("shw", "akza")])

G.add_edges_from([("akza", "ake"), ("ppg", "akza"), ("shw", "akza")])

G.add_edges_from([("ake", "hen3"), ("ake", "basfy")])

G.add_edges_from([("fbin", "mas"), ("fbin", "alle"), ("fbin", "gebn"), ("fbin", "assa b")])

G.add_edges_from([("alle", "jci"), ("fbin", "alle"), ("alle", "carr"), ("alle", "assa b")])

G.add_edges_from([("assa b", "jci"), ("alle", "assa b")])

G.add_edges_from([("jci", "sie"), ("jci", "hon"), ("jci", "carr"), ("jci", "tt"), ("jci", "lii")])

G.add_edges_from([("carr", "hon"), ("jci", "carr"), ("carr", "tt"), ("carr", "lii")])

G.add_edges_from([("hon", "mmm"), ("jci", "hon"), ("hon", "dd"), ("hon", "emr"), ("hon", "rtx"), ("hon", "ge")])

G.add_edges_from([("tt", "jci"), ("carr", "tt"), ("tt", "lii")])

G.add_edges_from([("lii", "jci"), ("carr", "lii"), ("tt", "lii")])

G.add_edges_from([("gebn", "fbin"), ("gebn", "mas"), ("gebn", "shw")])

G.add_edges_from([("sie", "su"), ("sie", "abbn"), ("sie", "rok")])

G.add_edges_from([("su", "lr"), ("su", "abbn"), ("sie", "su")])

G.add_edges_from([("abbn", "su"), ("hon", "abbn"), ("abbn", "rok")])

G.add_edges_from([("rok", "sie"), ("rok", "hon"), ("rok", "su"), ("rok", "abbn"), ("rok", "emr")])

G.add_edges_from([("emr", "sie"), ("emr", "hon"), ("emr", "su"), ("emr", "abbn"), ("rok", "emr")])

G.add_edges_from([("lr", "su"), ("lr", "abbn")])

G.add_edges_from([("mmm", "kmb"), ("mmm", "dd"), ("mmm", "avy"), ("mmm", "pg"), ("mmm", "kvue")])

G.add_edges_from([("dd", "mmm"), ("dd", "xyl")])

G.add_edges_from([("xyl", "pnr"), ("dhr", "xyl")])

G.add_edges_from([("pnr", "xyl"), ("dhr", "pnr"), ("pnr", "hayw"), ("iex", "pnr")])

G.add_edges_from([("rtx", "hon"), ("rtx", "txt"), ("rtx", "ba"), ("rtx", "ge")])

G.add_edges_from([("ge", "mtx"), ("rtx", "ge"), ("ge", "rr")])

G.add_edges_from([("mtx", "saf"), ("rtx", "mtx"), ("mtx", "rr"), ("mtx", "ge")])

G.add_edges_from([("rr", "saf"), ("rtx", "rr"), ("mtx", "rr"), ("rr", "ge")])

G.add_edges_from([("saf", "rtx"), ("mtx", "saf"), ("saf", "ge")])

G.add_edges_from([("txt", "gd"), ("txt", "ba"), ("txt", "lmt")])

G.add_edges_from([("ba", "air"), ("noc", "ba"), ("ba", "lmt")])

G.add_edges_from([("lmt", "rtx"), ("noc", "lmt"), ("ba", "lmt")])

G.add_edges_from([("noc", "lmt"), ("ba", "noc")])

G.add_edges_from([("air", "noc"), ("rtx", "air"), ("air", "ba"), ("air", "lmt")])

G.add_edges_from([("gd", "noc"), ("gd", "bae"), ("gd", "bbd"), ("gd", "lmt")])

G.add_edges_from([("avy", "hon"), ("avy", "mmm"), ("avy", "zbra")])

G.add_edges_from([("zbra", "hon"), ("zbra", "assa b"), ("panasonic (6752)", "zbra")])

G.add_edges_from([("panasonic (6752)", "catl (300750)"), ("panasonic (6752)", "casio (6952)"), ("panasonic (6752)", "sony (6758)"), ("panasonic (6752)", "samsung (005930)")])

G.add_edges_from([("kvue", "kmb"), ("kvue", "pg"), ("kvue", "ul")])

G.add_edges_from([("hayw", "xyl"), ("hayw", "iex"), ("hayw", "pnr")])

G.add_edges_from([("iex", "xyl"), ("ph", "iex"), ("iex", "ggg")])

G.add_edges_from([("ph", "hon"), ("ph", "etn"), ("ph", "rtx")])

G.add_edges_from([("etn", "su"), ("etn", "abbn"), ("etn", "cmi"), ("etn", "emr"), ("etn", "ph")])

G.add_edges_from([("cmi", "hon"), ("cmi", "cnh"), ("cmi", "cat")])

G.add_edges_from([("ggg", "ndsn"), ("ggg", "tt"), ("ggg", "iex")])

G.add_edges_from([("ndsn", "ggg"), ("ndsn", "iex")])

G.add_edges_from([("cnh", "de"), ("cnh", "cat"), ("cnh", "agco")])

G.add_edges_from([("cat", "de"), ("tex", "cat")])

G.add_edges_from([("de", "cnh"), ("de", "cat"), ("de", "agco")])

G.add_edges_from([("agco", "cnh"), ("de", "agco"), ("ctva", "agco")])

G.add_edges_from([("tex", "de"), ("tex", "cat")])

G.add_edges_from([("ctva", "fmc"), ("ctva", "ntr"), ("ctva", "bayry")])

G.add_edges_from([("fmc", "ctva"), ("fmc", "ntr"), ("fmc", "bayry")])

G.add_edges_from([("ntr", "ctva"), ("cf", "ntr"), ("ntr", "mos")])

G.add_edges_from([("cf", "apd"), ("cf", "ntr"), ("cf", "mos")])

G.add_edges_from([("mos", "sqm"), ("cf", "mos"), ("ntr", "mos")])

G.add_edges_from([("sqm", "laac"), ("sqm", "altm"), ("sqm", "mos"), ("sqm", "alb")])

G.add_edges_from([("bbd", "gd"), ("bbd", "txt"), ("bbd", "am")])

G.add_edges_from([("am", "ldo"), ("am", "rhm"), ("am", "gd"), ("am", "rtx")])

G.add_edges_from([("bae", "osk"), ("bae", "noc"), ("bae", "gd"), ("bae", "ba"), ("bae", "lmt")])

G.add_edges_from([("osk", "gd"), ("osk", "tex"), ("osk", "lmt")])

G.add_edges_from([("ldo", "bae"), ("ldo", "lmt"), ("ldo", "ho")])

G.add_edges_from([("ho", "alo"), ("ho", "bae"), ("ho", "gd"), ("ho", "lmt")])

G.add_edges_from([("alo", "sie"), ("alo", "bbd"), ("alo", "ge")])

G.add_edges_from([("rhm", "ldo"), ("rhm", "saab"), ("rhm", "gd"), ("rhm", "lmt")])

G.add_edges_from([("saab", "ldo"), ("saab", "rhm"), ("saab", "am")])

G.add_edges_from([("laac", "altm"), ("laac", "alb")])

G.add_edges_from([("altm", "sqm"), ("altm", "laac"), ("altm", "alb")])

G.add_edges_from([("alb", "sqm"), ("alb", "laac"), ("altm", "alb")])

G.add_edges_from([("sony (6758)", "umg"), ("sony (6758)", "wmg"), ("sony (6758)", "nintendo (7974)"), ("sony (6758)", "samsung (005930)"), ("sony (6758)", "panasonic (6752)")])

G.add_edges_from([("catl (300750)", "samsung sdi (006400)"), ("catl (300750)", "calb (03931)"), ("catl (300750)", "panasonic (6752)")])

G.add_edges_from([("casio (6952)", "uhr")])

G.add_edges_from([("uhr", "cfr"), ("uhr", "rms"), ("uhr", "mc")])

G.add_edges_from([("uhr", "cfr"), ("uhr", "rms"), ("uhr", "mc")])

G.add_edges_from([("samsung sdi (006400)", "catl (300750)"), ("samsung sdi (006400)", "tdk (6762)"), ("samsung sdi (006400)", "panasonic (6752)")])

G.add_edges_from([("calb (03931)", "catl (300750)"), ("calb (03931)", "samsung sdi (006400)"), ("calb (03931)", "panasonic (6752)")])

G.add_edges_from([("umg", "sony (6758)"), ("umg", "wmg"), ("umg", "spot")])

G.add_edges_from([("wmg", "sony (6758)"), ("umg", "wmg"), ("wmg", "spot")])

G.add_edges_from([("nintendo (7974)", "sony (6758)"), ("nintendo (7974)", "ea"), ("nintendo (7974)", "dis")])

G.add_edges_from([("cfr", "uhr"), ("cfr", "rms"), ("cfr", "mc")])

G.add_edges_from([("rms", "prada (01913)"), ("rms", "cfr"), ("rms", "ker"), ("rms", "mc")])

G.add_edges_from([("mc", "cfr"), ("mc", "ker"), ("rms", "mc")])

G.add_edges_from([("ker", "prada (01913)"), ("ker", "cfr"), ("rms", "ker"), ("ker", "mc"), ("ker", "tpr")])

G.add_edges_from([("prada (01913)", "cfr"), ("prada (01913)", "mc"), ("prada (01913)", "tpr")])

G.add_edges_from([("tpr", "cpri"), ("tpr", "rl"), ("rms", "tpr"), ("tpr", "mc"), ("ker", "tpr"), ("tpr", "sfer")])

G.add_edges_from([("cpri", "tpr"), ("cpri", "rl"), ("cpri", "pvh"), ("cpri", "mc"), ("ker", "cpri"), ("cpri", "sfer"), ("cpri", "boss")])

G.add_edges_from([("rl", "boss"), ("rl", "pvh"), ("rms", "rl"), ("rl", "mc"), ("rl", "tpr")])

G.add_edges_from([("sfer", "prada (01913)"), ("sfer", "ker")])

G.add_edges_from([("pvh", "gps"), ("pvh", "hbi"), ("pvh", "urbn"), ("pvh", "vfc"), ("pvh", "rl"), ("pvh", "boss")])

G.add_edges_from([("boss", "prada (01913)"), ("boss", "ker"), ("boss", "pvh"), ("boss", "rl")])

G.add_edges_from([("gps", "rost"), ("gps", "tjx"), ("gps", "urbn"), ("gps", "jwn"), ("gps", "kss"), ("gps", "m")])

G.add_edges_from([("urbn", "rost"), ("urbn", "tjx"), ("gps", "urbn"), ("urbn", "jwn"), ("urbn", "kss"), ("urbn", "m")])

G.add_edges_from([("rost", "tjx"), ("rost", "jwn"), ("rost", "m")])

G.add_edges_from([("tjx", "rost"), ("tjx", "jwn"), ("tjx", "m")])

G.add_edges_from([("jwn", "rost"), ("jwn", "tjx"), ("jwn", "kss"), ("jwn", "m")])

G.add_edges_from([("kss", "rost"), ("kss", "tjx"), ("gps", "kss"), ("kss", "jwn"), ("urbn", "kss"), ("kss", "m"), ("kss", "tgt")])

G.add_edges_from([("m", "rost"), ("m", "tjx"), ("m", "jwn"), ("kss", "m"), ("m", "tgt")])

G.add_edges_from([("hbi", "bbwi"), ("hbi", "pvh"), ("hbi", "gil"), ("hbi", "vfc"), ("hbi", "addyy"), ("hbi", "brk")])

G.add_edges_from([("vfc", "nke"), ("vfc", "pvh"), ("vfc", "rl"), ("hbi", "vfc"), ("vfc", "addyy"), ("vfc", "uaa")])

G.add_edges_from([("addyy", "nke"), ("addyy", "pum"), ("addyy", "li ning (02331)"), ("anta (02020)", "addyy"), ("addyy", "uaa")])

G.add_edges_from([("nke", "lulu"), ("nke", "pum"), ("nke", "li ning (02331)"), ("nke", "anta (02020)"), ("nke", "addyy"), ("nke", "uaa")])

G.add_edges_from([("uaa", "lulu"), ("uaa", "hbi"), ("uaa", "vfc"), ("uaa", "anta (02020)"), ("uaa", "addyy"), ("nke", "uaa")])

G.add_edges_from([("pum", "lulu"), ("nke", "pum"), ("pum", "li ning (02331)"), ("pum", "anta (02020)"), ("pum", "addyy"), ("pum", "uaa")])

G.add_edges_from([("li ning (02331)", "lulu"), ("nke", "li ning (02331)"), ("li ning (02331)", "anta (02020)"), ("li ning (02331)", "addyy")])

G.add_edges_from([("anta (02020)", "nke"), ("li ning (02331)", "anta (02020)"), ("anta (02020)", "addyy")])

G.add_edges_from([("lulu", "bbwi"), ("hbi", "lulu"), ("lulu", "nke"), ("lulu", "vfc"), ("lulu", "addyy"), ("lulu", "uaa")])

G.add_edges_from([("bbwi", "ulta"), ("bbwi", "wsm"), ("bbwi", "el")])

G.add_edges_from([("gil", "pvh"), ("hbi", "gil"), ("gil", "nke"), ("gil", "vfc"), ("gil", "addyy"), ("gil", "uaa")])

G.add_edges_from([("ulta", "wba"), ("ulta", "jwn"), ("ulta", "kss"), ("ulta", "tgt"), ("ulta", "m"), ("ulta", "wmt"), ("ulta", "cvs"), ("ulta", "amzn"), ("ulta", "mc")])

G.add_edges_from([("wsm", "rh"), ("w", "wsm"), ("wsm", "shw")])

G.add_edges_from([("rh", "wsm"), ("w", "rh"), ("rh", "mc")])

G.add_edges_from([("w", "wsm"), ("w", "rh"), ("w", "shw")])

G.add_nodes_from(["lly", "nvo", "mrk", "bmy"])
G.add_edges_from([("lly", "nvo"), ("lly", "mrk"), ("lly", "bmy")])

G.add_nodes_from(["nvo", "lly", "sny", "rhhby", "azn"])
G.add_edges_from([("lly", "nvo"), ("nvo", "sny"), ("nvo", "rhhby"), ("nvo", "azn")])

G.add_nodes_from(["mrk", "pfe", "lly", "bmy"])
G.add_edges_from([("mrk", "pfe"), ("lly", "mrk"), ("mrk", "bmy")])

G.add_nodes_from(["bmy", "lly", "mrk", "gsk", "pfe", "azn"])
G.add_edges_from([("lly", "bmy"), ("bmy", "mrk"), ("bmy", "gsk"), ("bmy", "azn"), ("bmy", "pfe")])

G.add_nodes_from(["pfe", "lly", "mrk", "gsk"])
G.add_edges_from([("lly", "pfe"), ("pfe", "mrk"), ("pfe", "gsk")])

G.add_nodes_from(["azn", "mrk", "pfe", "lly", "bmy"])
G.add_edges_from([("azn", "mrk"), ("azn", "pfe"), ("lly", "azn"), ("azn", "bmy")])

G.add_nodes_from(["gsk", "mrk", "pfe", "azn"])
G.add_edges_from([("gsk", "mrk"), ("gsk", "azn"), ("gsk", "pfe")])

G.add_nodes_from(["sny", "mrk", "pfe", "nvs"])
G.add_edges_from([("sny", "mrk"), ("sny", "nvs"), ("sny", "pfe")])

G.add_nodes_from(["rhhby", "mrk", "abbv", "regn"])
G.add_edges_from([("rhhby", "mrk"), ("rhhby", "abbv"), ("rhhby", "regn")])

G.add_nodes_from(["abbv", "mrk", "pfe", "lly", "jnj"])
G.add_edges_from([("abbv", "mrk"), ("abbv", "pfe"), ("lly", "abbv"), ("abbv", "jnj")])

G.add_nodes_from(["jnj", "mrk", "lly", "nvs", "pg"])
G.add_edges_from([("jnj", "mrk"), ("jnj", "nvs"), ("jnj", "lly"), ("jnj", "pg")])

G.add_nodes_from(["nvs", "jnj", "gsk"])
G.add_edges_from([("nvs", "gsk"), ("jnj", "nvs")])

G.add_nodes_from(["pg", "or", "chd", "kmb", "cl", "ul"])
G.add_edges_from([("pg", "or"), ("pg", "chd"), ("pg", "kmb"), ("pg", "cl"), ("pg", "ul")])

G.add_nodes_from(["regn", "amgn", "nvs", "rhhby"])
G.add_edges_from([("regn", "amgn"), ("regn", "nvs"), ("rhhby", "regn")])

G.add_nodes_from(["amgn", "nvs", "regn"])
G.add_edges_from([("nvs", "amgn"), ("amgn", "regn")])

G.add_nodes_from(["or", "el", "pg", "shiseido (4911)"])
G.add_edges_from([("pg", "or"), ("or", "el"), ("or", "shiseido (4911)")])

G.add_nodes_from(["chd", "rkt", "pg", "clx", "ul"])
G.add_edges_from([("chd", "rkt"), ("pg", "chd"), ("chd", "clx"), ("chd", "ul")])

G.add_nodes_from(["ul", "or", "chd", "rkt", "cl", "pg", "hen3", "bei"])
G.add_edges_from([("ul", "or"), ("ul", "chd"), ("ul", "rkt"), ("ul", "cl"), ("pg", "ul"), ("ul", "hen3"), ("bei", "ul")])

G.add_nodes_from(["cl", "rkt", "pg", "ul"])
G.add_edges_from([("cl", "rkt"), ("pg", "cl"), ("cl", "ul")])

G.add_nodes_from(["rkt", "chd", "ul", "pg", "hen3", "bayry"])
G.add_edges_from([("rkt", "chd"), ("ul", "rkt"), ("pg", "rkt"), ("rkt", "hen3"), ("rkt", "bayry")])

G.add_nodes_from(["hen3", "chd", "pg", "ul"])
G.add_edges_from([("hen3", "chd"), ("pg", "hen3"), ("hen3", "ul")])

G.add_nodes_from(["kmb", "kao (4452)", "pg", "ul", "unicharm (8113)"])
G.add_edges_from([("kmb", "kao (4452)"), ("pg", "kmb"), ("kmb", "ul"), ("kmb", "unicharm (8113)")])

G.add_edges_from([("bei", "or"), ("bei", "el"), ("bei", "ul")])

G.add_edges_from([("el", "or"), ("bei", "el"), ("el", "shiseido (4911)")])

G.add_edges_from([("shiseido (4911)", "or"), ("shiseido (4911)", "kao (4452)"), ("el", "shiseido (4911)")])

G.add_edges_from([("kao (4452)", "kmb"), ("pg", "kao (4452)"), ("kao (4452)", "cl"), ("kao (4452)", "bei")])

G.add_edges_from([("unicharm (8113)", "kao (4452)"), ("pg", "unicharm (8113)"), ("kmb", "unicharm (8113)"), ("essity", "unicharm (8113)"), ("unicharm (8113)", "hengan (01044)")])

G.add_edges_from([("clx", "chd"), ("clx", "pg"), ("clx", "ul")])

G.add_edges_from([("bayry", "pfe"), ("bayry", "basfy"), ("bayry", "bmy")])

G.add_edges_from([("essity", "pg"), ("essity", "unicharm (8113)")])

G.add_edges_from([("hengan (01044)", "pg"), ("kmb", "hengan (01044)"), ("unicharm (8113)", "hengan (01044)")])

G.add_edges_from([("ko", "pep"), ("ko", "kdp"), ("ko", "mnst"), ("ko", "nsrgy")])

G.add_edges_from([("pep", "ko"), ("pep", "kdp"), ("pep", "gis")])

G.add_edges_from([("kdp", "ko"), ("pep", "kdp"), ("kdp", "mnst")])

G.add_edges_from([("mnst", "ko"), ("pep", "mnst"), ("kdp", "mnst")])

G.add_edges_from([("nsrgy", "khc"), ("nsrgy", "mdlz"), ("nsrgy", "hsy"), ("gis", "nsrgy")])

G.add_edges_from([("gis", "k"), ("gis", "klg"), ("gis", "cag")])

G.add_edges_from([("khc", "cpb"), ("khc", "k"), ("nsrgy", "khc"), ("gis", "khc")])

G.add_edges_from([("k", "cpb"), ("k", "pep"), ("k", "nsrgy")])

G.add_edges_from([("cpb", "gis"), ("cpb", "pep"), ("cpb", "ul")])

G.add_edges_from([("mdlz", "hsy"), ("mdlz", "k"), ("mdlz", "gis"), ("mdlz", "nsrgy")])

G.add_edges_from([("hsy", "mdlz"), ("hsy", "cag"), ("hsy", "nsrgy")])

G.add_edges_from([("cag", "khc"), ("cag", "gis"), ("cag", "nsrgy")])

G.add_edges_from([("klg", "cag"), ("klg", "gis"), ("klg", "nsrgy")])

G.add_edges_from([("tmo", "a"), ("tmo", "wat"), ("tmo", "dhr"), ("tmo", "merck kgaa")])

G.add_edges_from([("a", "tmo"), ("a", "wat"), ("a", "dhr")])

G.add_edges_from([("wat", "tmo"), ("a", "wat"), ("wat", "dhr")])

G.add_edges_from([("dhr", "tmo"), ("dhr", "merck kgaa"), ("rhhby", "dhr")])

G.add_edges_from([("merck kgaa", "tmo"), ("biib", "merck kgaa"), ("merck kgaa", "dhr")])

G.add_edges_from([("biib", "nvs"), ("biib", "sny"), ("biib", "rhhby")])

G.add_nodes_from(["brk", "all", "pgr", "mkl"])
G.add_edges_from([("brk", "all"), ("brk", "pgr"), ("brk", "mkl")])

G.add_nodes_from(["all", "brk", "pgr", "trv"])
G.add_edges_from([("brk", "all"), ("all", "pgr"), ("all", "trv")])

G.add_nodes_from(["pgr", "brk", "all", "trv"])
G.add_edges_from([("brk", "pgr"), ("all", "pgr"), ("pgr", "trv")])

G.add_nodes_from(["trv", "pgr", "cb", "all"])
G.add_edges_from([("trv", "cb"), ("all", "trv"), ("pgr", "trv")])

G.add_nodes_from(["mkl", "ffh", "wrb", "trv"])
G.add_edges_from([("mkl", "ffh"), ("mkl", "wrb"), ("mkl", "trv")])

G.add_nodes_from(["cb", "brk", "aig", "trv"])
G.add_edges_from([("brk", "cb"), ("cb", "aig"), ("cb", "trv")])

G.add_nodes_from(["aig", "zurn", "cb", "trv"])
G.add_edges_from([("aig", "zurn"), ("cb", "aig"), ("aig", "trv")])

G.add_nodes_from(["zurn", "av", "axahy", "alv"])
G.add_edges_from([("av", "zurn"), ("zurn", "axahy"), ("zurn", "alv")])

G.add_nodes_from(["ffh", "mkl", "wrb", "trv"])
G.add_edges_from([("mkl", "ffh"), ("ffh", "wrb"), ("ffh", "trv")])

G.add_nodes_from(["wrb", "mkl", "aig", "trv"])
G.add_edges_from([("mkl", "wrb"), ("aig", "wrb"), ("wrb", "trv")])

G.add_nodes_from(["av", "zurn", "axahy", "alv"])
G.add_edges_from([("av", "zurn"), ("av", "axahy"), ("av", "alv")])

G.add_nodes_from(["axahy", "av", "zurn", "alv"])
G.add_edges_from([("axahy", "zurn"), ("av", "axahy"), ("axahy", "alv")])

G.add_nodes_from(["alv", "axahy", "av", "zurn"])
G.add_edges_from([("alv", "zurn"), ("av", "alv"), ("axahy", "alv")])

G.add_edges_from([("arm", "intc"), ("arm", "cdns"), ("arm", "snps")])

G.add_edges_from([("cdns", "sie"), ("anss", "cdns"), ("cdns", "snps")])

G.add_edges_from([("snps", "sie"), ("cdns", "snps")])

G.add_edges_from([("anss", "snps"), ("cdns", "anss"), ("anss", "adsk"), ("dsy", "anss")])

G.add_edges_from([("adsk", "dsy"), ("anss", "adsk"), ("adsk", "ptc")])

G.add_edges_from([("dsy", "adsk"), ("anss", "dsy"), ("dsy", "ptc")])

G.add_edges_from([("ptc", "adsk"), ("ptc", "sie"), ("dsy", "ptc")])

G.add_edges_from([("intu", "adp"), ("intu", "payx"), ("intu", "sge")])

G.add_edges_from([("adp", "pcty"), ("adp", "payx"), ("adp", "payc")])

G.add_edges_from([("payx", "pcty"), ("adp", "payx"), ("payx", "payc")])

G.add_edges_from([("pcty", "adp"), ("pcty", "payx"), ("pcty", "payc")])

G.add_edges_from([("payc", "adp"), ("payc", "payx"), ("pcty", "payc")])

G.add_edges_from([("sge", "xro"), ("sge", "sap"), ("intu", "sge")])

G.add_edges_from([("xro", "sge"), ("xro", "wday"), ("intu", "xro")])

G.add_edges_from([("abt", "bsx"), ("abt", "mdt"), ("abt", "rhhby")])

G.add_edges_from([("bsx", "abt"), ("bsx", "mdt"), ("bsx", "jnj"), ("bsx", "ew")])

G.add_edges_from([("mdt", "bsx"), ("abt", "mdt"), ("mdt", "jnj")])

G.add_edges_from([("ew", "mdt"), ("abt", "ew")])

net = Network(notebook=True, width="750px", height="750px", cdn_resources="remote")
net.from_nx(G)
net.barnes_hut(spring_length=100, spring_strength=1)
net.show('graph.html')
# Out:
# graph.html
#         <iframe
#             width="750px"
#             height="750px"
#             src="graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
G = nx.Graph()

G.add_edges_from([("tsla", "vwagy"), ("tsla", "bmw"), ("tsla", "f"), ("tsla", "gm")])

G.add_edges_from([("vwagy", "tm"), ("vwagy", "hmc"), ("vwagy", "nsany"), ("vwagy", "bmw"), ("vwagy", "tsla"), ("vwagy", "mbgaf"), ("vwagy", "rno"), ("vwagy", "f"), ("vwagy", "gm")])

G.add_edges_from([("bmw", "tm"), ("bmw", "vwagy"), ("bmw", "nsany"), ("bmw", "hmc"), ("bmw", "mbgaf"), ("bmw", "rno"), ("bmw", "f"), ("bmw", "gm")])

G.add_edges_from([("f", "tm"), ("f", "vwagy"), ("f", "nsany"), ("f", "hmc"), ("f", "tsla"), ("f", "stlam"), ("f", "rno"), ("f", "gm")])

G.add_edges_from([("gm", "tm"), ("gm", "vwagy"), ("gm", "nsany"), ("gm", "hmc"), ("gm", "mbgaf"), ("gm", "bmw"), ("gm", "tsla"), ("gm", "f")])

G.add_edges_from([("tm", "vwagy"), ("tm", "nsany"), ("tm", "hmc"), ("tm", "mbgaf"), ("tm", "bmw"), ("tm", "tsla"), ("tm", "f"), ("tm", "stlam"), ("tm", "rno"), ("tm", "gm")])

G.add_edges_from([("hmc", "tm"), ("hmc", "vwagy"), ("hmc", "nsany"), ("hmc", "bmw"), ("hmc", "tsla"), ("hmc", "mbgaf"), ("hmc", "f"), ("hmc", "stlam"), ("hmc", "gm")])

G.add_edges_from([("nsany", "tm"), ("nsany", "vwagy"), ("hmc", "nsany"), ("nsany", "bmw"), ("nsany", "mbgaf"), ("nsany", "rno"), ("nsany", "f"), ("nsany", "gm")])

G.add_edges_from([("mbgaf", "tm"), ("mbgaf", "vwagy"), ("mbgaf", "hmc"), ("mbgaf", "nsany"), ("mbgaf", "bmw"), ("mbgaf", "tsla"), ("mbgaf", "stlam"), ("mbgaf", "rno"), ("mbgaf", "f"), ("mbgaf", "gm")])

G.add_edges_from([("rno", "tm"), ("rno", "vwagy"), ("rno", "hmc"), ("rno", "nsany"), ("rno", "bmw"), ("rno", "mbgaf"), ("rno", "f"), ("rno", "gm")])

G.add_edges_from([("stlam", "tm"), ("stlam", "vwagy"), ("stlam", "hmc"), ("stlam", "nsany"), ("stlam", "bmw"), ("stlam", "mbgaf"), ("stlam", "rno"), ("stlam", "f"), ("stlam", "gm")])

net = Network(notebook=True, width="750px", height="750px", cdn_resources="remote")
net.from_nx(G)
net.barnes_hut(spring_length=100, spring_strength=0.5)
net.show('graph.html')
# Out:
# graph.html
#         <iframe
#             width="750px"
#             height="750px"
#             src="graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
G = nx.Graph()

G.add_edges_from([("jpm", "c"), ("jpm", "wfc"), ("jpm", "bac")])

G.add_edges_from([("c", "jpm"), ("c", "wfc"), ("c", "bac")])

G.add_edges_from([("wfc", "jpm"), ("c", "wfc"), ("wfc", "bac")])

G.add_edges_from([("bac", "jpm"), ("c", "bac"), ("wfc", "bac")])

G.add_edges_from([("ms", "gs"), ("ms", "bac"), ("ms", "sf"), ("ms", "rjf")])

G.add_edges_from([("gs", "ms"), ("gs", "sf"), ("gs", "rjf")])

G.add_edges_from([("sf", "ms"), ("lpla", "sf"), ("sf", "rjf")])

G.add_edges_from([("rjf", "lpla"), ("rjf", "bac"), ("rjf", "sf"), ("ms", "rjf")])

G.add_edges_from([("lpla", "amp"), ("lpla", "sf"), ("lpla", "rjf")])

G.add_edges_from([("amp", "lpla"), ("amp", "sf"), ("amp", "rjf")])

G.add_edges_from([("hsbc", "dbs (d05)"), ("hsbc", "c"), ("hsbc", "jpm")])

G.add_edges_from([("dbs (d05)", "ocbc (o39)"), ("dbs (d05)", "uob (u11)"), ("dbs (d05)", "bochk (02388)"), ("dbs (d05)", "hang seng bank (00011)")])

G.add_edges_from([("ocbc (o39)", "dbs (d05)"), ("ocbc (o39)", "uob (u11)"), ("ocbc (o39)", "bochk (02388)"), ("ocbc (o39)", "hang seng bank (00011)")])

G.add_edges_from([("uob (u11)", "dbs (d05)"), ("ocbc (o39)", "uob (u11)"), ("uob (u11)", "bochk (02388)"), ("uob (u11)", "hang seng bank (00011)")])

G.add_edges_from([("bochk (02388)", "dbs (d05)"), ("ocbc (o39)", "bochk (02388)"), ("uob (u11)", "bochk (02388)"), ("bochk (02388)", "hang seng bank (00011)")])

G.add_edges_from([("hang seng bank (00011)", "dbs (d05)"), ("ocbc (o39)", "hang seng bank (00011)"), ("hang seng bank (00011)", "hsbc"), ("bochk (02388)", "hang seng bank (00011)")])

net = Network(notebook=True, width="750px", height="750px", cdn_resources="remote")
net.from_nx(G)
net.show('graph.html')
# Out:
# graph.html
#         <iframe
#             width="750px"
#             height="750px"
#             src="graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
G = nx.Graph()

G.add_edges_from([("xom", "shell"), ("xom", "cvx"), ("xom", "tte"), ("xom", "bp")])

G.add_edges_from([("shell", "xom"), ("shell", "tte"), ("shell", "bp")])

G.add_edges_from([("tte", "e"), ("tte", "shell"), ("tte", "cvx"), ("tte", "bp")])

G.add_edges_from([("bp", "shell"), ("bp", "cvx"), ("bp", "tte"), ("xom", "bp")])

G.add_edges_from([("cvx", "xom"), ("cvx", "tte"), ("cvx", "bp")])

G.add_edges_from([("e", "rep"), ("e", "tte"), ("e", "shell")])

G.add_edges_from([("rep", "bp"), ("rep", "tte"), ("rep", "shell")])

net = Network(notebook=True, width="750px", height="750px", cdn_resources="remote")
net.from_nx(G)
net.barnes_hut(spring_length=100, spring_strength=1)
net.show('graph.html')
# Out:
# graph.html
#         <iframe
#             width="750px"
#             height="750px"
#             src="graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
G = nx.Graph()

G.add_edges_from([("asml", "amat"), ("asml", "klac"), ("asml", "lrcx")])

G.add_edges_from([("amat", "klac"), ("amat", "lrcx")])

G.add_edges_from([("klac", "amat"), ("asml", "klac"), ("klac", "lrcx")])

G.add_edges_from([("lrcx", "klac"), ("amat", "lrcx")])

net = Network(notebook=True, width="750px", height="750px", cdn_resources="remote")
net.from_nx(G)
net.show('graph.html')
# Out:
# graph.html
#         <iframe
#             width="750px"
#             height="750px"
#             src="graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
G = nx.Graph()

G.add_edges_from([("mcd", "cmg"), ("mcd", "yum"), ("mcd", "qsr")])

G.add_edges_from([("cmg", "mcd"), ("cmg", "yum"), ("cmg", "qsr"), ("cmg", "sbux")])

G.add_edges_from([("yum", "dpz"), ("mcd", "yum"), ("yum", "qsr")])

G.add_edges_from([("qsr", "yumc"), ("mcd", "qsr"), ("yum", "qsr")])

G.add_edges_from([("yumc", "dpz"), ("mcd", "yumc"), ("yum", "yumc")])

G.add_edges_from([("dpz", "yum"), ("mcd", "dpz"), ("dpz", "qsr")])

G.add_edges_from([("sbux", "yum"), ("sbux", "mcd"), ("sbux", "qsr")])

net = Network(notebook=True, width="750px", height="750px", cdn_resources="remote")
net.from_nx(G)
net.barnes_hut(spring_length=100, spring_strength=1)
net.show('graph.html')
# Out:
# graph.html
#         <iframe
#             width="750px"
#             height="750px"
#             src="graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
G = nx.Graph()

G.add_edges_from([("txn", "nxpi"), ("txn", "adi"), ("txn", "mchp")])

G.add_edges_from([("nxpi", "txn"), ("nxpi", "stm"), ("nxpi", "mchp"), ("nxpi", "ifnny")])

G.add_edges_from([("mchp", "nxpi"), ("mchp", "stm"), ("txn", "mchp")])

G.add_edges_from([("stm", "txn"), ("nxpi", "stm"), ("stm", "on"), ("stm", "ifnny")])

G.add_edges_from([("ifnny", "txn"), ("nxpi", "ifnny"), ("ifnny", "on"), ("stm", "ifnny")])

G.add_edges_from([("on", "nxpi"), ("on", "stm"), ("on", "ifnny")])

G.add_edges_from([("adi", "nxpi"), ("txn", "adi"), ("adi", "mchp")])

net = Network(notebook=True, width="750px", height="750px", cdn_resources="remote")
net.from_nx(G)
net.barnes_hut(spring_length=100, spring_strength=1)
net.show('graph.html')
# Out:
# graph.html
#         <iframe
#             width="750px"
#             height="750px"
#             src="graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
G = nx.Graph()

G.add_edges_from([("pm", "bti"), ("pm", "imbby"), ("pm", "mo"), ("pm", "japan tobacco (2914)")])

net = Network(notebook=True, width="750px", height="750px", cdn_resources="remote")
net.from_nx(G)
net.show('graph.html')
# Out:
# graph.html
#         <iframe
#             width="750px"
#             height="750px"
#             src="graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
