# %%
# old_health = health
# old_education = education
# old_crime_rate = crime_rate
# old_violent_crime_rate = violent_crime_rate
# old_poverty_rate = poverty_rate
# old_equality = equality
# old_environment = environment
# old_working_week = working_week
# old_technology = technology
# old_car_usage = car_usage
# old_rail_usage = rail_usage
# old_bus_usage = bus_usage
# old_worker_productivity = worker_productivity
# old_unemployment = unemployment
# old_co2_emissions = co2_emissions
# old_air_travel = air_travel
# old_immigration = immigration
# old_energy_efficiency = energy_efficiency
# old_racial_tension = racial_tension
# old_foreign_relations = foreign_relations
# old_international_trade = international_trade
# old_oil_demand = oil_demand
# old_oil_supply = oil_supply
# old_oil_price = oil_price
# old_terrorism = terrorism
# old_low_income = low_income
# old_middle_income = middle_income
# old_high_income = high_income
# old_gdp = gdp
# old_private_healthcare = private_healthcare
# old_private_housing = private_housing
# old_private_schools = private_schools
# old_private_pensions = private_pensions
# old_tobacco_use = tobacco_use
# old_alcohol_consumption = alcohol_consumption
# old_traffic_congestion = traffic_congestion
# old_tourism = tourism
# old_wages = wages
# old_legal_drug_consumption = legal_drug_consumption
# old_currency_strength = currency_strength
# old_food_price = food_price
# old_average_temperature = average_temperature
# old_lifespan = lifespan
# old_internet_currency_adoption = internet_currency_adoption
# old_industrial_automation = industrial_automation

# %%
import matplotlib.pyplot as plt

# %%
health = [0.5]
education = [0.18]
crime_rate = [0.55]
violent_crime_rate = [0.57]
poverty_rate = [0.64]
equality = [0.4]
environment = [0.5]
working_week = [0.5]
technology = [0.5]
car_usage = [0.6]
rail_usage = [0.25]
bus_usage = [0.15]
worker_productivity = [0.5]
unemployment = [0.4]
co2_emissions = [0.2]
air_travel = [0]
immigration = [1]
energy_efficiency = [0.5]
racial_tension = [0]
foreign_relations = [0.14]
international_trade = [0.5]
oil_demand = [0.1]
oil_supply = [0.5]
oil_price = [0.5]
terrorism = [0.5]
low_income = [0]
middle_income = [0]
high_income = [0]
gdp = [0.35]
private_healthcare = [0.6]
private_housing = [0.5]
private_schools = [0.5]
private_pensions = [0.5]
tobacco_use = [0.5]
alcohol_consumption = [0.4]
traffic_congestion = [0.25]
tourism = [0.35]
wages = [0.5]
legal_drug_consumption = [0]
currency_strength = [0.5]
food_price = [0.2]
average_temperature = [0]
lifespan = [0]
internet_currency_adoption = [0]
industrial_automation = [0]

skills_shortage_val = [0.75]
pollution_val = [0]
uncompetitive_economy_val = [0.8]
technological_advantage_val = [0]
high_productivity_val = [0]
street_gangs_val = [0]
antisocial_behaviour_val = [0.8]
general_strike_val = [0]
technology_backwater_val = [1]
inner_city_riots_val = [0]
organized_crime_val = [0.75]
alcoholism_val = [0.4]
vigilante_mobs_val = [0.3]
armed_robbery_val = [0]
contagious_disease_val = [0.6]
teachers_strike_val = [0.88]
asthma_epidemic_val = [0.8]
hospital_overcrowding_val = [0.6]
drug_addiction_val = [0.6]
teacher_shortage_val = [1]
doctors_strike_val = [0.7]
brain_drain_val = [0]
petrol_protests_val = [0]
black_market_val = [0]
tax_evasion_val = [0.3]
rail_strike_val = [1]
homelessness_val = [0.1]
class_warfare_val = [0]
gridlock_val = [0]
internet_crime_val = [0]
debt_crisis_val = [0]
corporate_exodus_val = [0]
race_riots_val = [0]
ghettos_val = [0]
obesity_val = [0.3]
cyber_warfare_val = [0]

skills_shortage = False
pollution = False
uncompetitive_economy = False
technological_advantage = False
high_productivity = False
street_gangs = False
antisocial_behaviour = False
general_strike = False
technology_backwater = False
inner_city_riots = False
organized_crime = False
alcoholism = False
vigilante_mobs = False
armed_robbery = False
contagious_disease = False
teachers_strike = False
asthma_epidemic = False
hospital_overcrowding = False
drug_addiction = False
teacher_shortage = False
doctors_strike = False
brain_drain = False
petrol_protests = False
black_market = False
tax_evasion = False
rail_strike = False
homelessness = False
class_warfare = False
gridlock = False
internet_crime = False
debt_crisis = False
corporate_exodus = False
race_riots = False
ghettos = False
obesity = False
cyber_warfare = False

# %%
iters = 400

for i in range(1, iters + 1):
    current_health = health[0] - 0.24*working_week[i-1]**8 + 0.3*private_healthcare[max(0, i-4)]**0.6 - 0.06*tobacco_use[max(0, i-12)] - 0.03*alcohol_consumption[max(0, i-12)] - 0.22*legal_drug_consumption[i-1]**2 - 0.05*food_price[i-1]
    current_education = education[0] + 0.16*technology[i-1]-0.1 - 0.3*private_schools[max(0, i-8)]**0.6+0.07
    current_crime_rate = crime_rate[0] - 0.12*education[i-1]**6 + 0.41*poverty_rate[max(0, i-4)]**2 - 0.22*equality[i-1]+0.1 + 0.17*unemployment[i-1]**5 + 0.06*alcohol_consumption[i-1]
    current_violent_crime_rate = violent_crime_rate[0] - 0.12*education[i-1]**4 + 0.45*racial_tension[i-1]**6 + 0.11*alcohol_consumption[i-1]
    current_poverty_rate = poverty_rate[0] + 0.24*unemployment[i-1]**8
    current_equality = equality[0] - 0.15*gdp[i-1]**4 - 0.1*private_healthcare[max(0, i-4)] - 0.1*private_housing[max(0, i-4)] - 0.1*private_schools[max(0, i-8)] - 0.2*private_pensions[max(0, i-4)]
    current_environment = environment[0] - 0.22*car_usage[i-1] - 0.14*air_travel[i-1]**3 - 0.84*gdp[i-1]**2
    current_working_week = working_week[0] + 0.2*unemployment[i-1] - 0.25*industrial_automation[max(0, i-2)]+0.1
    current_technology = technology[0]
    current_car_usage = car_usage[0] + 0.4*gdp[i-1] - 0.35*rail_usage[i-1] - 0.35*bus_usage[i-1] + 0.1*low_income[i-1]**3 + 0.2*middle_income[i-1]**3 + 0.2*high_income[i-1]**2
    current_rail_usage = rail_usage[0] + 0.1*gdp[i-1] - 0.28*bus_usage[i-1] - 0.04*air_travel[i-1]
    current_bus_usage = bus_usage[0] + 0.1*gdp[i-1] - 0.25*rail_usage[i-1] - 0.05*low_income[i-1]
    current_worker_productivity = worker_productivity[0] + 0.15*health[i-1]-0.15 + 0.4*education[i-1]-0.2 + 0.15*technology[i-1]**4 + 0.3*unemployment[i-1]-0.215 - 0.17*alcohol_consumption[i-1] - 0.4*wages[i-1]+0.2 - 0.04*legal_drug_consumption[i-1] + 0.1*industrial_automation[max(0, i-16)]+0.02
    current_unemployment = unemployment[0] + 0.2*technology[max(0, i-2)]**8 + 0.16*worker_productivity[max(0, i-2)]-0.08 + 0.3*immigration[max(0, i-2)]**3 - 0.7*gdp[i-1]+0.9 - 0.07*private_healthcare[i-1] - 0.13*private_schools[i-1] + 0.23*industrial_automation[max(0, i-10)]
    current_co2_emissions = co2_emissions[0] + 0.5*car_usage[i-1] + 0.32*air_travel[i-1]**2 - 0.2*energy_efficiency[i-1] + 0.6*gdp[i-1] + 0.1*traffic_congestion[i-1]
    current_air_travel = air_travel[0] + 0.2*international_trade[i-1] + 0.1*low_income[i-1]**4 + 0.2*middle_income[i-1]**3 + 0.3*high_income[i-1]**2 + gdp[i-1]
    current_immigration = immigration[0] + 0.1*health[i-1]**6 - 0.2*unemployment[i-1]**2+0.05 + 0.2*foreign_relations[i-1]-0.1 + 0.98*gdp[max(0, i-4)]**4
    current_energy_efficiency = energy_efficiency[0]
    current_racial_tension = racial_tension[0] - 0.08*education[i-1] + 0.22*poverty_rate[max(0, i-2)] + 0.7*unemployment[max(0, i-2)]**3 + 1.4*immigration[max(0, i-8)]**3 - 0.6*foreign_relations[i-1]+0.3
    current_foreign_relations = foreign_relations[0] - 0.1*co2_emissions[i-1]
    current_international_trade = international_trade[0] + 0.4*worker_productivity[max(0, i-4)]-0.2 + 0.2*foreign_relations[max(0, i-4)]-0.2 - 0.4*currency_strength[max(0, i-4)]+0.2
    current_oil_demand = oil_demand[0] + 0.3*car_usage[i-1] + 0.12*rail_usage[i-1] + 0.13*bus_usage[i-1] + 0.1*air_travel[i-1] - 0.1*energy_efficiency[i-1] + 0.4*gdp[i-1]
    current_oil_supply = oil_supply[0] - 0.015*i
    current_oil_price = oil_price[0] + 0.5*oil_demand[i-1] - 0.5*oil_supply[i-1]
    current_terrorism = terrorism[0] + racial_tension[i-1]**4-0.2 + foreign_relations[i-1]-0.24 + 0.01*i
    current_low_income = low_income[0] - 0.15*private_healthcare[max(0, i-4)] - 0.17*private_housing[i-1] - 0.17*private_schools[i-1] + wages[i-1]-0.5 - food_price[i-1]**1.2
    current_middle_income = middle_income[0] - 0.08*private_healthcare[max(0, i-4)] - 0.08*private_housing[i-1] - 0.08*private_schools[i-1] - 0.1*private_pensions[i-1] + 0.6*wages[i-1]-0.3 - 0.3*food_price[i-1]
    current_high_income = high_income[0]
    current_gdp = gdp[0] - 0.08*crime_rate[i-1] + 0.44*worker_productivity[i-1]-0.22 + 0.035*immigration[i-1]-0.035 + 0.05*energy_efficiency[i-1] + 0.15*international_trade[i-1] - 0.4*oil_price[i-1]+0.22 - 0.1*traffic_congestion[i-1]**2 + 0.12*tourism[i-1]
    current_private_healthcare = private_healthcare[0] + 0.4*gdp[max(0, i-4)]
    current_private_housing = private_housing[0] + 0.5*gdp[max(0, i-4)]
    current_private_schools = private_schools[0] + 0.5*gdp[max(0, i-4)]
    current_private_pensions = private_pensions[0] + 0.5*gdp[max(0, i-4)]
    current_tobacco_use = tobacco_use[0] + 0.4*gdp[i-1]
    current_alcohol_consumption = alcohol_consumption[0] + 0.1*gdp[i-1]**0.5 + 0.2*poverty_rate[i-1]**2 + 0.2*unemployment[i-1]**2 - 0.3*legal_drug_consumption[max(0, i-2)]
    current_traffic_congestion = traffic_congestion[0] + car_usage[i-1]**1.5
    current_tourism = tourism[0] - 0.1*crime_rate[max(0, i-8)] - 0.2*violent_crime_rate[max(0, i-8)] + 0.4*foreign_relations[max(0, i-4)] + 0.1*environment[max(0, i-8)]-0.1 - 0.24*currency_strength[max(0, i-2)]+0.12
    current_wages = wages[0] - 0.4*unemployment[i-1]+0.2 - 0.22*immigration[i-1]
    current_legal_drug_consumption = legal_drug_consumption[0]
    current_currency_strength = currency_strength[0] + gdp[max(0, i-2)]-0.5
    current_food_price = food_price[0] + 0.6*average_temperature[i-1]**2 - 0.2*international_trade[i-1]-0.2 + 0.2*oil_price[i-1] + 0.03*lifespan[i-1]
    current_average_temperature = average_temperature[0] + 0.035*i + 0.25*co2_emissions[i-1]
    current_lifespan = lifespan[0] + 0.02*i-0.1 + 0.65*health[max(0, i-4)] + 0.4*environment[max(0, i-6)]-0.2 + 0.15*technology[max(0, i-8)] - 0.2*violent_crime_rate[i-1]
    current_internet_currency_adoption = internet_currency_adoption[0] + 0.001*i + 0.42*technology[max(0, i-4)] + 0.18*middle_income[i-1]
    current_industrial_automation = industrial_automation[0] + 0.004*i + 0.4*technology[i-1]**0.8

    #situations
    curr_skills_shortage_val = skills_shortage_val[0] - 0.4*education[i-1] - 0.2*immigration[i-1] + 0.25*technology[i-1]**2
    if curr_skills_shortage_val >= 0.6:
        skills_shortage = True
    elif curr_skills_shortage_val <= 0.4:
        skills_shortage = False

    curr_pollution_val = pollution_val[0] - environment[i-1]+1
    if curr_pollution_val >= 0.6:
        pollution = True
    elif curr_pollution_val <= 0.4:
        pollution = False

    curr_uncompetitive_economy_val = uncompetitive_economy_val[0] - 0.7*worker_productivity[i-1]+1
    if curr_uncompetitive_economy_val >= 0.6:
        uncompetitive_economy = True
    elif curr_uncompetitive_economy_val <= 0.4:
        uncompetitive_economy = False

    curr_technological_advantage_val = technological_advantage_val[0] + 0.7*technology[i-1]
    if curr_technological_advantage_val >= 0.6:
        technological_advantage = True
    elif curr_technological_advantage_val <= 0.4:
        technological_advantage = False

    curr_high_productivity_val = high_productivity_val[0] + 0.95*worker_productivity[i-1]**2
    if curr_technological_advantage_val >= 0.6:
        high_productivity = True
    elif curr_high_productivity_val <= 0.4:
        high_productivity = False

    curr_street_gangs_val = street_gangs_val[0] + 0.84*poverty_rate[i-1] + 0.6*unemployment[i-1]+0.1 + 0.1*homelessness_val[max(0, i-2)]
    if curr_street_gangs_val >= 0.6:
        street_gangs = True
    elif curr_street_gangs_val <= 0.4:
        street_gangs = False

    curr_street_gangs_val = street_gangs_val[0] + 0.84*poverty_rate[i-1] + 0.6*unemployment[i-1]+0.1 + 0.1*homelessness_val[max(0, i-2)]
    if curr_street_gangs_val >= 0.6:
        street_gangs = True
    elif curr_street_gangs_val <= 0.4:
        street_gangs = False

    health.append(max(min(current_health, 1), 0))
    education.append(max(min(current_education, 1), 0))
    crime_rate.append(max(min(current_crime_rate, 1), 0))
    violent_crime_rate.append(max(min(current_violent_crime_rate, 1), 0))
    poverty_rate.append(max(min(current_poverty_rate, 1), 0))
    equality.append(max(min(current_equality, 1), 0))
    environment.append(max(min(current_environment, 1), 0))
    working_week.append(max(min(current_working_week, 1), 0))
    technology.append(max(min(current_technology, 1), 0))
    car_usage.append(max(min(current_car_usage, 1), 0))
    rail_usage.append(max(min(current_rail_usage, 1), 0))
    bus_usage.append(max(min(current_bus_usage, 1), 0))
    worker_productivity.append(max(min(current_worker_productivity, 1), 0))
    unemployment.append(max(min(current_unemployment, 1), 0))
    co2_emissions.append(max(min(current_co2_emissions, 1), 0))
    air_travel.append(max(min(current_air_travel, 1), 0))
    immigration.append(max(min(current_immigration, 1), 0))
    energy_efficiency.append(max(min(current_energy_efficiency, 1), 0))
    racial_tension.append(max(min(current_racial_tension, 1), 0))
    foreign_relations.append(max(min(current_foreign_relations, 1), 0))
    international_trade.append(max(min(current_international_trade, 1), 0))
    oil_demand.append(max(min(current_oil_demand, 1), 0))
    oil_supply.append(max(min(current_oil_supply, 1), 0))
    oil_price.append(max(min(current_oil_price, 1), 0))
    terrorism.append(max(min(current_terrorism, 1), 0))
    low_income.append(max(min(current_low_income, 1), -1))
    middle_income.append(max(min(current_middle_income, 1), -1))
    high_income.append(max(min(current_high_income, 1), -1))
    gdp.append(max(min(current_gdp, 1), 0))
    private_healthcare.append(max(min(current_private_healthcare, 1), 0))
    private_housing.append(max(min(current_private_housing, 1), 0))
    private_schools.append(max(min(current_private_schools, 1), 0))
    private_pensions.append(max(min(current_private_pensions, 1), 0))
    tobacco_use.append(max(min(current_tobacco_use, 1), 0))
    alcohol_consumption.append(max(min(current_alcohol_consumption, 1), 0))
    traffic_congestion.append(max(min(current_traffic_congestion, 1), 0))
    tourism.append(max(min(current_tourism, 1), 0))
    wages.append(max(min(current_wages, 1), 0))
    legal_drug_consumption.append(max(min(current_legal_drug_consumption, 1), 0))
    currency_strength.append(max(min(current_currency_strength, 1), 0))
    food_price.append(max(min(current_food_price, 1), 0))
    average_temperature.append(max(min(current_average_temperature, 1), 0))
    lifespan.append(max(min(current_lifespan, 1), 0))
    internet_currency_adoption.append(max(min(current_internet_currency_adoption, 1), 0))
    industrial_automation.append(max(min(current_industrial_automation, 1), 0))

# %%
plt.title("health")
plt.plot(health)
plt.show()

plt.title("education")
plt.plot(education)
plt.show()

plt.title("crime_rate")
plt.plot(crime_rate)
plt.show()

plt.title("violent_crime_rate")
plt.plot(violent_crime_rate)
plt.show()

plt.title("poverty_rate")
plt.plot(poverty_rate)
plt.show()

plt.title("equality")
plt.plot(equality)
plt.show()

plt.title("environment")
plt.plot(environment)
plt.show()

plt.title("working_week")
plt.plot(working_week)
plt.show()

plt.title("technology")
plt.plot(technology)
plt.show()

plt.title("car_usage")
plt.plot(car_usage)
plt.show()

plt.title("rail_usage")
plt.plot(rail_usage)
plt.show()

plt.title("bus_usage")
plt.plot(bus_usage)
plt.show()

plt.title("worker_productivity")
plt.plot(worker_productivity)
plt.show()

plt.title("unemployment")
plt.plot(unemployment)
plt.show()

plt.title("co2_emissions")
plt.plot(co2_emissions)
plt.show()

plt.title("air_travel")
plt.plot(air_travel)
plt.show()

plt.title("immigration")
plt.plot(immigration)
plt.show()

plt.title("energy_efficiency")
plt.plot(energy_efficiency)
plt.show()

plt.title("racial_tension")
plt.plot(racial_tension)
plt.show()

plt.title("foreign_relations")
plt.plot(foreign_relations)
plt.show()

plt.title("international_trade")
plt.plot(international_trade)
plt.show()

plt.title("oil_demand")
plt.plot(oil_demand)
plt.show()

plt.title("oil_supply")
plt.plot(oil_supply)
plt.show()

plt.title("oil_price")
plt.plot(oil_price)
plt.show()

plt.title("terrorism")
plt.plot(terrorism)
plt.show()

plt.title("low_income")
plt.plot(low_income)
plt.show()

plt.title("middle_income")
plt.plot(middle_income)
plt.show()

plt.title("high_income")
plt.plot(high_income)
plt.show()

plt.title("gdp")
plt.plot(gdp)
plt.show()

plt.title("private_healthcare")
plt.plot(private_healthcare)
plt.show()

plt.title("private_housing")
plt.plot(private_housing)
plt.show()

plt.title("private_schools")
plt.plot(private_schools)
plt.show()

plt.title("private_pensions")
plt.plot(private_pensions)
plt.show()

plt.title("tobacco_use")
plt.plot(tobacco_use)
plt.show()

plt.title("alcohol_consumption")
plt.plot(alcohol_consumption)
plt.show()

plt.title("traffic_congestion")
plt.plot(traffic_congestion)
plt.show()

plt.title("tourism")
plt.plot(tourism)
plt.show()

plt.title("wages")
plt.plot(wages)
plt.show()

plt.title("legal_drug_consumption")
plt.plot(legal_drug_consumption)
plt.show()

plt.title("currency_strength")
plt.plot(currency_strength)
plt.show()

plt.title("food_price")
plt.plot(food_price)
plt.show()

plt.title("average_temperature")
plt.plot(average_temperature)
plt.show()

plt.title("lifespan")
plt.plot(lifespan)
plt.show()

plt.title("internet_currency_adoption")
plt.plot(internet_currency_adoption)
plt.show()

plt.title("industrial_automation")
plt.plot(industrial_automation)
plt.show()
