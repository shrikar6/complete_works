# %%
movies = {
    "interstellar": {"epic", "intense", "brooding"},
    "her": {"amusing", "profound", "passionate"},
    "inception": {"surreal", "dreamlike", "thrilling"},
    "the lord of the rings the fellowship of the ring": {"epic", "thrilling", "sweeping"},
    "the lord of the rings the two towers": {"epic"},
    "the lord of the rings the return of the king": {"epic", "fantastic", "poignant"},
    "dune": {"epic", "fascinating", "sweeping"},
    "arrival": {"epic", "compelling", "thought provoking"},
    "hacksaw ridge": {"harrowing", "unflinching", "powerful"},
    "2001 a space odyssey": {"epic", "surreal", "atmospheric"},
    "dr strangelove": {"subversive", "psychological", "cynical"},
    "spartacus": {"epic", "sweeping", "exciting"},
    "citizen kane": {"profound", "sensational", "enigmatic"},
    "the irishman": {'epic', 'unflinching', 'brooding'},
    "silence": {"epic", "spiritual", "emotional"},
    "the wolf of wall street": {"irreverent", "confident", "rousing"},
    "hugo": {"heartwarming", "dreamlike", "spectacular"},
    "shutter island": {"macabre", "eerie", "thrilling"},
    "the departed": {"intense", "biting", "violent"},
    "the aviator": {"epic", "fascinating", "poignant"},
    "gangs of new york": {"epic", "dangerous", "hateful"},
    "kundun": {"epic", "spiritual"},
    "casino": {"epic", "intense", "gritty"},
    "goodfellas": {"ruthless", "volatile", "gritty"},
    "the last temptation of christ": {"epic", "passionate", "visceral"},
    "the king of comedy": {"amusing", "dark", "satirical"},
    "the godfather": {"epic", "brooding", "suspenseful"},
    "the godfather part ii": {"epic", "brooding", "suspenseful"},
    "the godfather part iii": {"contemplative", "vicious", "compelling"},
    "apocalypse now": {"epic", "ominous", "contemplative"},
    "gosford park": {"intricate", "satirical", "witty"},
    "the fabelmans": {"ambitious", "inspiring", "compelling"},
    "ready player one": {"amusing", "intense", "electrifying"},
    "the post": {"thoughtful", "tense", "compelling"},
    "bridge of spies": {"harrowing", "intense", "compelling"},
    "lincoln": {"epic", "inspiring", "anxious"},
    "war horse": {"heartfelt", "poignant", "stirring"},
    "the adventures of tintin": {"sweeping", "eccentric", "exciting"},
    "raiders of the lost ark": {"thrilling", "suspenseful", "humorous"},
    "indiana jones and the temple of doom": {"goofy", "gruesome", "exciting"},
    "indiana jones and the last crusade": {"nail-biting", "fun", "thrilling"},
    "indiana jones and the kingdom of the crystal skull": {"nail-biting", "amusing", "thrilling"},
    "munich": {"unflinching", "suspenseful", "thrilling"},
    "catch me if you can": {"suspenseful", "upbeat", "witty"},
    "minority report": {"intense", "thrilling", "enigmatic"},
    "saving private ryan": {"epic", "unflinching", "powerful"},
    "amistad": {"profound", "tense", "sweeping"},
    "jurassic park": {"intense", "thrilling", "engaging"},
    "the lost world jurassic park": {"intense", "thrilling", "engaging"},
    "jurassic park iii": {"intense", "thrilling", "engaging"},
    "jurassic world": {"electrifying", "confident", "uneasy"},
    "jurassic world fallen kingdom": {"fantastic", "frightening", "thrilling"},
    "jurassic world dominion": {"fantastic", "epic", "harrowing"},
    "schindlers list": {"epic", "sweeping", "dangerous"},
    "empire of the sun": {"brooding", "poignant", "suspenseful"},
    "the color purple": {"compelling", "heart-rending", "moving"},
    "e.t. the extra-terrestrial": {"wondrous", "charming", "enchanted"},
    "close encounters of the third kind": {"intense", "mysterious", "mind bending"},
    "the hateful eight": {"violent", "bleak", "suspenseful"}
}
