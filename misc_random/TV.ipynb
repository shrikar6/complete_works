# %%
import numpy as np

# %%
showdict = {
    "The Sopranos": np.mean([1,1,1,3,2,1,5]),
    "The Wire": np.mean([2,2,2,4,1,4,3]),
    "Breaking Bad": np.mean([3,3,5,1,4,2,1]),
    "Mad Men": np.mean([4,5,3,10,5,3,35]),
    "The Twilight Zone": np.mean([5,6,35,35,3,14,10]),
    "Freaks and Geeks": np.mean([6,35,35,35,26,35,19]),
    "Game of Thrones": np.mean([7,4,6,2,7,5,2]),
    "The West Wing": np.mean([8,10,14,5,10,7,20]),
    "Curb your enthusiasm": np.mean([9,18,13,35,25,16,33]),
    "Louie": np.mean([10,35,35,35,27,35,35]),
    "Deadwood": np.mean([11,14,16,12,12,21,35]),
    "Friday Night Lights": np.mean([11,35,26,35,32,26,35]),
    "Veep": np.mean([12,35,35,35,21,28,35]),
    "The X Files": np.mean([13,15,35,16,17,8,35]),
    "30 Rock": np.mean([14,21,11,21,15,25,35]),
    "Law & Order": np.mean([15,35,35,35,33,35,35]),
    "Orange is the New Black": np.mean([16,23,35,35,35,35,35]),
    "Buffy the Vampire Slayer": np.mean([17,17,35,7,14,6,35]),
    "Lost": np.mean([18,7,35,8,6,17,35]),
    "The Shield": np.mean([19,26,35,24,34,22,35]),
    "NYPD Blue": np.mean([20,24,35,35,13,35,35]),
    "The Americans": np.mean([21,35,27,35,35,35,35]),
    "Battlestar Galactica": np.mean([22,12,35,11,9,13,27]),
    "The Office": np.mean([23,8,23,32,31,35,15]),
    "ER": np.mean([24,27,35,25,35,35,35]),
    "Fargo": np.mean([25,33,35,35,24,23,11]),
    "Six Feet Under": np.mean([26,28,35,26,18,32,30]),
    "24": np.mean([27,29,35,17,28,18,35]),
    "Downton Abbey": np.mean([28,35,32,35,35,35,35]),
    "The Walking Dead": np.mean([29,25,35,23,35,35,35]),
    "House of Cards": np.mean([30,35,35,35,35,35,14]),
    "Doctor Who": np.mean([31,9,30,9,22,10,35]),
    "Homeland": np.mean([32,35,35,35,35,35,35]),
    "Oz": np.mean([33,34,35,35,35,27,35]),
    "Eastbound & Down": np.mean([34,35,35,35,35,35,35]),
    "Broadwalk Empire": np.mean([35,11,35,35,35,35,35]),
    "Band of Brothers": np.mean([35,13,35,14,11,19,35]),
    "Peaky Blinders": np.mean([35,16,35,15,35,35,35]),
    "Parks and Recreation": np.mean([35,19,35,18,8,20,35]),
    "Sherlock": np.mean([35,20,35,20,35,35,7]),
    "Better Call Saul": np.mean([35,21,31,22,23,35,24]),
    "Sons of Anarchy": np.mean([35,30,35,27,35,35,35]),
    "Stranger Things": np.mean([35,31,35,33,35,35,13]),
    "Fleabag": np.mean([35,32,7,34,35,35,35]),
    "The Thick of It": np.mean([35,35,4,35,35,35,35]),
    "Peep Show": np.mean([35,35,8,35,35,35,35]),
    "Atlanta": np.mean([35,35,9,35,35,12,35]),
    "Happy Valley": np.mean([35,35,10,35,35,35,35]),
    "Line of Duty": np.mean([35,35,12,35,35,35,35]),
    "Nighty Night": np.mean([35,35,15,35,35,35,35]),
    "Black Mirror": np.mean([35,35,17,35,35,35,35]),
    "The Handmaid's Tale": np.mean([35,35,18,35,35,35,35]),
    "Red Riding": np.mean([35,35,19,35,35,35,35]),
    "The Killing": np.mean([35,35,20,35,35,35,35]),
    "Spaced": np.mean([35,35,21,35,35,30,35]),
    "Killing Eve": np.mean([35,35,22,30,35,35,35]),
    "Detectorists": np.mean([35,35,24,35,35,35,35]),
    "The Good Wife": np.mean([35,35,25,35,35,35,35]),
    "The Crown": np.mean([35,35,28,35,35,35,31]),
    "The Bridge": np.mean([35,35,29,35,35,35,35]),
    "Patrick Melrose": np.mean([35,35,33,35,35,35,35]),
    "The Good Fight": np.mean([35,35,34,35,35,35,35]),
    "The OA": np.mean([35,35,35,6,35,35,35]),
    "The Leftovers": np.mean([35,35,35,13,19,9,35]),
    "Chernobyl": np.mean([35,35,35,19,35,35,35]),
    "It's Always Sunny in Philadelphia": np.mean([35,35,35,28,30,33,17]),
    "Firefly": np.mean([35,35,35,29,35,34,9]),
    "Hannibal": np.mean([35,35,35,31,35,15,35]),
    "Futurama": np.mean([35,35,35,35,16,35,35]),
    "Community": np.mean([35,35,35,35,20,29,35]),
    "Cowboy Bebop": np.mean([35,35,35,35,29,35,35]),
    "House": np.mean([[35,35,35,35,35,11,22]]),
    "Bojack Horseman": np.mean([[35,35,35,35,35,24,34]]),
    "I'm Alan Partridge": np.mean([[35,35,35,35,35,31,35]]),
    "Rick and Morty": np.mean([[35,35,35,35,35,35,4]]),
    "Avatar: The Last Airbender": np.mean([[35,35,35,35,35,35,6]]),
    "True Detective": np.mean([[35,35,35,35,35,35,8]]),
    "Gravity Falls": np.mean([[35,35,35,35,35,35,12]]),
    "Narcos": np.mean([[35,35,35,35,35,35,16]]),
    "The Mandalorian": np.mean([[35,35,35,35,35,35,18]]),
    "The Queen's Gambit": np.mean([[35,35,35,35,35,35,21]]),
    "Westworld": np.mean([[35,35,35,35,35,35,23]]),
    "Dark": np.mean([[35,35,35,35,35,35,25]]),
    "Rome": np.mean([[35,35,35,35,35,35,26]]),
    "The Haunting of Hill House": np.mean([[35,35,35,35,35,35,28]]),
    "The Boys": np.mean([[35,35,35,35,35,35,29]]),
    "Dragon Ball Z": np.mean([[35,35,35,35,35,35,32]])
}

# %%
shows = []
showvals = []
for i in showdict.keys():
    shows += [i]
    showvals += [showdict[i]]

idxs = np.argsort(showvals)
for i in idxs:
    print(shows[i])
