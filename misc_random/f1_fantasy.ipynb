# %%
import numpy as np

# %%
albon = {
    'abu': [6*21/9,2*21/14,9],
    'aus': [9*21/12,2],
    'aut': [10*21/12,2*21/14,5],
    'aze': [6*21/12,5],
    'bel': [2*21/9,6*21/14,2],
    'bhr': [3*21/12,1*21/14,9],
    'bra': [9*21/9,15],
    'can': [12*21/12,9],
    'emi': [14*21/14,4],
    'esp': [6*21/12,8*21/14,17],
    'fra': [10*21/12,9],
    'gbr': [8*21/12,4*21/14,21],
    'hun': [4*21/12,4*21/14,16],
    'jpn': [1*21/9,21],
    'mex': [2*21/9,5],
    'mon': [2*21/12,14*21/14,21],
    'rus': [2*21/9,9*21/14],
    'sin': [6*21/9,21],
    'usa': [2*21/9,9],
}

# %%
magnussen = {
    'abu': [13*22/19,21*22/21,10*22/20,10*22/21,11*22/21,10*22/14,15],
    'aus': [1*22/19,4*22/21,20*22/20,21*22/21,1*22/21,8],
    'aut': [3*22/19,6*22/21,20*22/20,1*22/21,19*22/21,2*22/14,2],
    'aze': [6*22/21,1*22/20,13*22/21,7*22/21,22],
    'bel': [14*22/19,21*22/21,14*22/20,6*22/21,6*22/21,8*22/14,11],
    'bhr': [19*22/19,3*22/21,20*22/20,1*22/21,7*22/21,5*22/14,1],
    'bra': [6*22/19,6*22/21,20*22/20,8*22/21,5*22/21,22],
    'can': [6*22/19,12*22/21,7*22/20,13*22/21,15*22/21,15],
    'chn': [17*22/19,14*22/21,2*22/20,10*22/21,7*22/21],
    'emi': [14*22/14,3],
    'esp': [14*22/19,10*22/21,13*22/20,3*22/21,2*22/21,5*22/14,15],
    'fra': [3*22/21,15*22/21,22],
    'ger': [6*22/19,12*22/21,12*22/21,3*22/21],
    'gbr': [3*22/19,14*22/21,7*22/20,8*22/21,21*22/21,14*22/14,6],
    'hun': [14*22/19,10*22/21,10*22/20,5*22/21,7*22/21,1*22/14,11],
    'ita': [10*22/19,14*22/21,6*22/20,17*22/21,21*22/21,14*22/14,11],
    'jpn': [18*22/19,6*22/21,2*22/20,21*22/21,13*22/21,8],
    'mal': [6*22/19,21*22/21,7*22/20],
    'mex': [14*22/21,2*22/20,16*22/21,13*22/21,15],
    'mon': [10*22/19,21*22/21,5*22/20,13*22/21,11*22/21,22],
    'rus': [2*22/19,1*22/21,10*22/20,6*22/21,4*22/21,2*22/14],
    'sin': [10*22/19,2*22/21,20*22/20,18*22/21,15*22/21,7],
    'usa': [5*22/19,4*22/21,15*22/20,21*22/21,18*22/21,3],
}

# %%
bottas = {
    'abu': [11*22/19,3*22/19,15*22/18,21*22/21,1*22/20,12*22/21,16*22/21,3*22/14,13*22/21,15],
    'aus': [8*22/19,8*22/19,7*22/21,10*22/20,19*22/21,1*22/21,6],
    'aut': [3*22/19,6*22/18,10*22/21,1*22/20,21*22/21,12*22/21,1*22/14,2*22/21,10],
    'aze': [5*22/21,4*22/20,20*22/21,1*22/21,15*22/21,10],
    'bel': [11*22/19,3*22/19,13*22/18,7*22/21,16*22/20,9*22/21,12*22/21,3*22/14,15*22/21,22],
    'bhr': [8*22/19,14*22/19,3*22/18,10*22/21,10*22/20,1*22/21,5*22/21,12*22/14,3*22/21,2],
    'bra': [19*22/19,17*22/19,6*22/18,16*22/21,4*22/20,12*22/21,21*22/21,3*22/21,7],
    'can': [8*22/19,12*22/19,1*22/18,1*22/21,4*22/20,1*22/21,16*22/21,4],
    'chn': [6*22/19,12*22/19,12*22/18,14*22/21,19*22/20,1*22/21,5*22/21],
    'emi': [3*22/14,21*22/21,1],
    'esp': [14*22/19,8*22/19,3*22/18,3*22/21,20*22/20,1*22/21,5*22/21,8*22/14,3*22/21,2],
    'fra': [18*22/21,5*22/21,11*22/21,14],
    'gbr': [3*22/19,1*22/19,6*22/18,18*22/21,4*22/20,9*22/21,5*22/21,8*22/14,3*22/21,22],
    'ger': [14*22/19,14*22/14,],
    'ger2': [1*22/19,10*22/21,1*22/21,21*22/21],
    'hun': [19*22/19,14*22/19,15*22/18,10*22/21,10*22/20,12*22/21,19*22/21,8*22/14,21*22/21,17],
    'ita': [11*22/19,7*22/19,3*22/18,5*22/21,4*22/20,8*22/21,5*22/21,11*22/14,3*22/21,13],
    'jpn': [17*22/19,11*22/19,6*22/18,14*22/21,14*22/20,1*22/21,1*22/21,15],
    'mal': [2*22/19,14*22/19,6*22/18,3*22/21,16*22/20],
    'mex': [1*22/18,7*22/21,4*22/20,12*22/21,12*22/21,17*22/21,9],
    'mon': [3*22/19,19*22/19,17*22/18,17*22/21,14*22/20,12*22/21,12*22/21,21*22/21,7],
    'ned': [3*22/21,22],
    'por': [3*22/14,3*22/21,],
    'rus': [3*22/19,14*22/18,2*22/21,1*22/20,1*22/21,5*22/21,1*22/14,12*22/21,],
    'sau': [3*22/21,22],
    'sin': [6*22/19,18*22/19,6*22/18,21*22/21,10*22/20,9*22/21,18*22/21,10],
    'tur': [13*22/14,1*22/21,],
    'usa': [1*22/19,8*22/19,18*22/18,19*22/21,16*22/20,12*22/21,1*22/21,13*22/21,22],
}

for gp in bottas:
    bottas[gp] = sum(bottas[gp])/len(bottas[gp])

# %%
races = [race for race in bottas]
rank = [bottas[race] for race in races]
argsorted = np.argsort(rank)
races_ranked = [races[i] for i in argsorted]
ranks_sorted = [rank[i] for i in argsorted]

inc = 0.75*22/len(races)
start = 0
stop = 0
while stop < (len(races)-1)/2:
    while ranks_sorted[start] + inc > ranks_sorted[stop]:
        stop += 1
        print("stop: " + str(stop))
    start = stop + 1
    print("start: " + str(start))
# Out:
# stop: 1
# start: 2
# stop: 2
# stop: 3
# start: 4
# stop: 4
# stop: 5
# stop: 6
# stop: 7
# start: 8
# stop: 8
# stop: 9
# stop: 10
# stop: 11
# stop: 12
# stop: 13
# start: 14
# stop: 14
# stop: 15
# stop: 16
# stop: 17
# start: 18

# %%
ranks_sorted[:14]
# Out:
# [3.928571428571429,
#  5.526075605680869,
#  6.454657477025898,
#  7.828320802005012,
#  7.8468114731272625,
#  8.090225563909774,
#  8.119448621553884,
#  8.670426065162907,
#  8.7603007518797,
#  9.116004296455424,
#  9.238095238095239,
#  9.272562358276645,
#  9.320501253132832,
#  9.558730158730159]

# %%
# albon: mex, bel, bhr, usa, aze, aut, abu
# kmag: rus, aut, ger, hun, bhr, aus, esp, aze, chn
# bottas: por, rus, can, esp, aut, bhr, ita, ger2, gbr, aus, emi, mex, mal, aze
